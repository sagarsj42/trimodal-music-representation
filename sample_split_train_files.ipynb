# %%
import os
os.chdir('../data')

os.getcwd()
# Out:
# '/Users/sagar/ms-iiit/is-music/data'

# %%
import glob
import math
import json
import random

from pydub import AudioSegment
from moviepy.editor import *

# %%
SEED_VALUE = 15
DOWN_DATA_DIR = './yt8m-av-down-data'
AUDIO_CLIPS_DATA_DIR = './yt8m-audio-clips'
VIDEO_CLIPS_DATA_DIR = './yt8m-video-clips'
split = 'train1'

# %%
threshold = 8
clip_off_first = 4
clip_off_last = 4
audio_format = 'mp3'
video_format = 'mp4'

# %%
random.seed(SEED_VALUE)

input_split_dir = os.path.join(DOWN_DATA_DIR, split)
audio_output_split_dir = os.path.join(AUDIO_CLIPS_DATA_DIR, split)
video_output_split_dir = os.path.join(VIDEO_CLIPS_DATA_DIR, split)
audio_info_file_name = f'audio-clips-info-{split}.jsonl'
video_info_file_name = f'video-clips-info-{split}.jsonl'
skipped_vids_file_name = f'skipped-vids-{split}.txt'

os.makedirs(audio_output_split_dir, exist_ok=True)
os.makedirs(video_output_split_dir, exist_ok=True)
os.system(f"touch ./{AUDIO_CLIPS_DATA_DIR}/{audio_info_file_name}")
os.system(f"touch ./{VIDEO_CLIPS_DATA_DIR}/{video_info_file_name}")
os.system(f"touch ./{skipped_vids_file_name}")
# Out:
# 0

# %%
done_v = list()
with open(os.path.join(VIDEO_CLIPS_DATA_DIR, video_info_file_name), 'r') as f:
    # print(json.loads(f.read().split('\n')[0]))
    for l in f.read().split('\n'):
        try:
            done_v.append(json.loads(l)['vid'])
        except:
            print(l)
    # done_v = [json.loads(l)['vid'] for l in f.read().split('\n')]

len(done_v), done_v[:5]
# Out:
# (136,
#  ['2iFnunNbwRc', 'BKZpGeOeuiE', '7ZZqaL6fWsc', '29qbpq__Tfw', '8QTfmpmeZhg'])

# %%
done_a = list()
with open(os.path.join(AUDIO_CLIPS_DATA_DIR, audio_info_file_name), 'r') as f:
    # print(json.loads(f.read().split('\n')[0]))
    for l in f.read().split('\n'):
        try:
            done_a.append(json.loads(l)['vid'])
        except:
            print(l)
    # done_v = [json.loads(l)['vid'] for l in f.read().split('\n')]

len(done_a), done_a[:5]
# Out:
# (136,
#  ['2iFnunNbwRc', 'BKZpGeOeuiE', '7ZZqaL6fWsc', '29qbpq__Tfw', '8QTfmpmeZhg'])

# %%
set(done_a) == set(done_v)
# Out:
# True

# %%
for vid in os.listdir(input_split_dir):
    if vid in done_a:
        continue
    print(vid, end='\t')
    if len(os.listdir(os.path.join(input_split_dir, vid))) < 2:
        with open(skipped_vids_file_name, 'a') as f:
            f.write(vid + f' | # files, {len(os.listdir(os.path.join(input_split_dir, vid)))} < 2' + '\n')
        continue
    
    audio_file = glob.glob(pathname=f'{input_split_dir}/{vid}/{vid}-audio.*')[0]
    audio_segment = AudioSegment.from_file(audio_file)

    a_dur_ms = len(audio_segment)
    a_dur_sec = len(audio_segment)/1000
    a_start = clip_off_first*1000
    a_end = a_start
    a_clips = list()
    while a_start < (a_dur_ms - clip_off_last*1000):
        a_end += threshold*1000
        clip = audio_segment[a_start:a_end]
        a_clips.append(clip)
        a_start += threshold*1000
    
    video_file = glob.glob(pathname=f'{input_split_dir}/{vid}/{vid}-video.*')[0]
    try:
        video_object = VideoFileClip(video_file)
    except OSError as e:
        print('Converting to mp4, video file:', video_file)
        vid_dir = os.path.join(input_split_dir, vid)
        filename = os.path.basename(video_file)
        new_filename = filename.split('.')[0] + '.mp4'
        os.system(f'cd {input_split_dir}/{vid} && MP4Box -add {filename} {new_filename} >/dev/null 2>&1')
        video_object = VideoFileClip(os.path.join(vid_dir, new_filename))
    
    v_dur = video_object.duration
    v_start = clip_off_first
    v_end = v_start
    v_clips = list()
    while v_start < (v_dur - clip_off_last):
        v_end += threshold
        clip = video_object.subclip(v_start, min(v_end, v_dur))
        v_clips.append(clip)
        v_start += threshold

    if len(a_clips) != len(v_clips):
        with open(skipped_vids_file_name, 'a') as f:
            f.write(vid + f' | # audio clips, {len(a_clips)} != # video clips, {len(v_clips)}' + '\n')
        continue

    n_sample_clips = math.ceil(v_dur / 40)
    clip_indxs = random.sample(range(len(a_clips)), n_sample_clips)
    print(len(a_clips), len(v_clips), n_sample_clips)
    sampled_a_clips = [a_clips[i] for i in clip_indxs]
    sampled_v_clips = [v_clips[i] for i in clip_indxs]
    a_sampled_dur_sec = sum([len(c) for c in sampled_a_clips]) / 1000.0
    v_sampled_dur_sec = sum([c.duration for c in sampled_v_clips])

    os.makedirs(os.path.join(audio_output_split_dir, vid), exist_ok=True)
    os.makedirs(os.path.join(video_output_split_dir, vid), exist_ok=True)
    for ci, ac, vc in zip(clip_indxs, a_clips, v_clips):
        ac.export(os.path.join(audio_output_split_dir, vid, f'{vid}-audio-{ci+1}.{audio_format}'), 
                format=audio_format)
        vc.write_videofile(os.path.join(video_output_split_dir, vid, f'{vid}-video-{ci+1}.{video_format}'), 
                verbose=False, logger=None)

    a_info = {
        'vid': vid,
        'duration_sec': a_dur_sec,
        'n_clips': len(a_clips),
        'n_sampled_clips': n_sample_clips,
        'sampled_dur': a_sampled_dur_sec
    }
    v_info = {
        'vid': vid,
        'duration_sec': v_dur,
        'n_clips': len(v_clips),
        'n_sampled_clips': n_sample_clips,
        'sampled_dur': v_sampled_dur_sec
    }
    with open(os.path.join(AUDIO_CLIPS_DATA_DIR, audio_info_file_name), 'a') as f:
        f.write(json.dumps(a_info) + '\n')
    with open(os.path.join(VIDEO_CLIPS_DATA_DIR, video_info_file_name), 'a') as f:
        f.write(json.dumps(v_info) + '\n')
# Out:
# -tnjaABj98Q	-BctSYCVZ_4	-VWwVI_rm0s	-9Qn0cHdBcQ	-dXDxRTJyKA	-P6Cjqv7Eg8	--V2p2Qk6P8	9_Qn-ywn4TM	-wFFzYNblEs	-rd7A4dChCM	-guZ-ahqKv0	-YNFGmhHWg0	-RGnFhPBB1g	-B6bdGJn-js	-7IldlbIRQo	3hJtwflQAuk	37 37 8
# 8BOBg17CHZE	30 30 7
# 6j2cnEjkDuc	32 32 7
# 8kd4GNKcvc0	30 30 7
# 592Rzj3B9BA	28 28 6
# 8YMh_aEhuIo	24 24 5
# 7eeQ4jNXfZU	56 56 12
# 19y6bov-37Y	31 31 7
# 7kmPUZI-HLo	Converting to mp4, video file: ./yt8m-av-down-data/train1/7kmPUZI-HLo/7kmPUZI-HLo-video.webm
# 33 33 7
# 9OtNHcsjoQo	33 33 7
# 72TvBNE5iWU	26 26 6
# 5JB58uwvGAo	50 50 11
# 10orCGhqp6I	30 30 7
# 59Aj9E5lCn0	31 31 7
# 5e-Jlg_yoHw	53 53 11
# 8ovSSRHZrmQ	32 32 7
# 9K8jdWEsWvI	55 55 12
# AUauEhwjEtk	25 25 6
# 36tj2eTQ9i8	29 29 6
# 1StOosGxRrY	41 41 9
# 0zxCotE1ckM	30 30 7
# 3qX-TEPINKE	36 36 8
# Am_LvH0V-Lg	28 28 6
# 3lZcuDoTK1M	42 42 9
# AO8d0gdDRjw	37 37 8
# 8e9Y0U-qzxI	Converting to mp4, video file: ./yt8m-av-down-data/train1/8e9Y0U-qzxI/8e9Y0U-qzxI-video.webm
# 58 58 12
# ApyyhiAiHi0	22 22 5
# 4KTcLBL2v7w	24 24 5
# 4iqrophXguY	24 24 5
# 0dGVbjuigek	34 34 7
# AuM74bjU260	45 45 10
# AxFYSiWrGyU	21 21 5
# -UyM6jJzuVw	95UgzR6Qqug	17 17 4
# 0ak8tdM-nag	31 31 7
# 1-cZAWOoSZM	31 31 7
# 5VYgPbBWoAY	37 37 8
# 7tIKyg1biOI	59 59 12
# 5Eu5ULb6e8U	44 44 9
# 67c4-D2LpVg	5gPJkGCyFw8	42 42 9
# 3YkIJ9guF6Y	34 34 7
# 5_BGoOBF0vU	24 24 5
# 1M2f4bvIqSQ	24 24 5
# 5b2EQf57Qn4	34 34 7
# 1A9rZOGp7TU	27 27 6
# 1EKe7pEbZmY	Converting to mp4, video file: ./yt8m-av-down-data/train1/1EKe7pEbZmY/1EKe7pEbZmY-video.webm
# 4gN6AoOxmBA	31 31 7
# 7OoC73MRiYU	25 25 6
# 8petkoTNT7A	30 30 7
# 7YOyA1oy5bo	47 47 10
# 6wMtuUr6gfQ	50 50 11
# 9d8WJRkV1Ko	38 38 8
# B5k8I0G8mUM	16 16 4
# 4jzjETKql2o	36 36 8
# 4w-s-7wYcgc	31 31 7
# 0ET4JMN6bSI	28 28 6
# 6I1RoJb57kQ	36 36 8
# 5Y1UPAX5pa0	33 33 7
# 6rWsuXrho7U	29 29 6
# 1fG2tclqkXM	25 25 6
# 57MhT1QqXAM	18 18 4
# 3r98qNN590Q	34 34 7
# 92IwybG4toc	25 25 6
# 9tH-IjRjfOA	29 29 6
# 9Q2HTZlFdkg	24 24 5
# 9FBdozr6NpM	25 25 6
# 2jFJmZrTN5o	22 22 5
# 2lP81EMYumo	24 24 5
# 1cKPIBys89k	24 24 5
# -mE_M9KEKug	2xDNPx7K-bs	25 25 6
# 0PVQ-9lvSOU	24 24 5
# 3Qwg8t8mD6A	24 24 5
# 9H-NFirHtS4	21 21 5
# 9iGu_vkBO6Y	26 26 6
# 9R_WyyKnNto	28 28 6
# 0mltoM-XcHk	17 17 4
# 565zwDuUyDg	40 40 9
# 4e8L_Z0a_kQ	27 27 6
# 4K0m5be7yX8	36 36 8
# 4Txv0wsqxKY	42 42 9
# 47kyNBmwC9g	35 35 8
# Ae6K8BP79iY	40 40 9
# 1gQpu_Ciyug	54 54 11
# AyTRgU2nl-g	46 46 10
# 6GZxDe8LcEU	15 15 4
# 5kSHZvJE15I	28 28 6
# AFUqrOsl2rU	41 41 9
# 8-7pelKGwqA	26 26 6
# 6Hr3b8mRk_w	Converting to mp4, video file: ./yt8m-av-down-data/train1/6Hr3b8mRk_w/6Hr3b8mRk_w-video.webm
# 24 24 5
# -fcvn1IWc-o	0tSEcf-JLcY	37 37 8
# 4eNv0r_kmnA	23 23 5
# 1ZV3NIIsWtI	22 22 5
# AWTCqNKNpDc	34 34 7
# 9kbNQ4IPtk8	39 39 8
# 5l2tjpSXVuo	27 27 6
# -ZaRdbUOKbA	7WCl0pOQ6iM	55 55 12
# 5UHkTPPgn7Q	41 41 9
# 2PN7FAk1V-M	45 45 10
# 56zh4wunacw	30 30 7
# 6yqIhRbXzJk	29 29 6
# 4kvnSX85CJM	27 27 6
# 9PtQSDYW3lg	17 17 4
# 5hjxgQIpkYg	30 30 7
# -WBXzPEVzOg	4WC99oSkrRE	21 21 5
# -wwzv9emNHE	2ulpfaldOxM	Converting to mp4, video file: ./yt8m-av-down-data/train1/2ulpfaldOxM/2ulpfaldOxM-video.webm
# 19 19 4
# 3CMnhJ_cOC8	29 29 6
# 10pJsy81bGk	31 31 7
# 7xeTkJS8si8	33 33 7
# 4-wK3gjszkQ	23 23 5
# 3LR3AEb2RHo	33 33 7
# 4E2n-Br8No0	48 48 10
# 4UsY2N-xuNM	36 36 8
# 7-EqWFoVcZI	21 21 5
# 9Q3fkTHX01Y	41 41 9
# 2qJ4QakrTCs	25 25 6
# 6tYxoY826eA	23 23 5
# 91Iu6OxlnUU	Converting to mp4, video file: ./yt8m-av-down-data/train1/91Iu6OxlnUU/91Iu6OxlnUU-video.webm
# 59 59 12
# 4nldUUhFy6A	39 39 8
# 53uPBfZA6gs	23 23 5
# 8KDZDTI3TUE	26 26 6
# 5BJbcOnj5ac	28 28 6
# 3mOyXUGLj6c	36 36 8
# 3gQZM_cKv8c	28 28 6
# 7Ng_s1KU94I	32 32 7
# 1jC4f_6sEY8	52 52 11
# APEn6J9G-fU	20 20 5
# 62sZtY93y38	28 28 6
# 5uALLQLvdi4	42 42 9
# ACIJyJEpeM8	55 55 12
# 1LUeNIOWMD4	30 30 7
# BA9K0AcI0Qk	28 28 6
# 32ZjwKdLvGw	28 28 6
# 2qYtdH8v3uI	23 23 5
# 3U1KMOhQCzA	25 25 6
# 9I4Zn4SCUME	20 20 5
# 5oaL1pA1Rec	25 25 6
# 1SZ_NpuJEBY	36 36 8
# 0YxTSOzQXhQ	15 15 4
# 2bGN9q6_ijA	41 41 9
# 683XNr463HQ	39 39 8
# 7D_U-kBhnV8	27 27 6
# 8DCE80G38x4	35 35 8
# 6P9dQlak36w	27 27 6
# BNs0nnSpLR8	37 37 8
# 3VET2eq0Ta4	28 28 6
# 4ckz89v3H9s	38 38 8
# Al3OLzBhUPI	24 24 5
# 5akYnlwubDo	28 28 6
# 9mPRBF5mWss	54 54 11
# -HebkIyy-oE	4HJ3dpDaqJw	4rJf37qQqU0	49 49 10
# 2xpANQbpbkw	29 29 6
# 6val7pqEeJk	31 31 7
# 4SMD76Hji9o	27 27 6
# 7ORXracGbug	29 29 6
# 00AQIz7Ixzk	41 41 9
# 97W45Zq5D3Y	30 30 7
# -6qHqh2JWE8	AUKLvhnLL80	33 33 7
# 0JB6x2B_HCA	16 16 4
# AtaCr3iGpOU	41 41 9
# 7bnI6860QdM	18 18 4
# 8nCIgqlN7oY	31 31 7
# -WBxPWMMJ8E	9biHYmw6JUc	34 34 7
# 4c2lhN_pb60	34 34 7
# 5UZF3bGoZpM	26 26 6
# -n4vuddlxFs	422ClkLAtUU	53 53 11
# 3t31Re9KG9E	24 24 5
# 7LZgSUNnnrw	24 24 5
# 080uT1aZwEA	28 28 6
# 6u63jhX3ZF8	26 26 6
# 6gci0fY56xg	51 51 11
# 2Iqigk6l1P8	22 22 5
# Aq_UxnkKOLo	41 41 9
# BQGDLtwcZD4	19 19 4
# 0fnjyod6R6M	28 28 6
# 1pbFtaf-by8	24 24 5
# 09_qQ-lQlgs	28 28 6
# 9zLZnNj6MRk	-vJUvecTTR0	1vH82RD9Gb0	57 57 12
# 1S6oEDZ66rU	33 33 7
# 3ucnJtps4t8	26 26 6
# 55bcVN3IrpE	25 25 6
# 7ROP7187EkA	32 32 7
# 7bTSw3U3JKI	Converting to mp4, video file: ./yt8m-av-down-data/train1/7bTSw3U3JKI/7bTSw3U3JKI-video.webm
# 29 29 6
# 2hHITovd7aQ	30 30 7
# 3w6MW4cdCjE	17 17 4
# 72m8mUcx_4A	36 36 8
# 0RIakZqncxg	23 23 5
# 9imC3X_fBVQ	25 25 6
# 8nd3qxXj2tw	35 35 8
# 0-ZSPr7mccQ	33 33 7
# 1J8deFQZBd4	40 40 9
# 1rPOg6VnzV8	28 28 6
# 7Sx7aDdh-f4	15 15 4
# AC9ww4Z-Qa8	40 40 9
# AGmUsPp1yKI	38 38 8
# 5741EMS9790	22 22 5
# 5F70frw9-VU	Converting to mp4, video file: ./yt8m-av-down-data/train1/5F70frw9-VU/5F70frw9-VU-video.webm
# 31 31 7
# 0htnMgzCN64	39 39 8
# 8DVg01zTAYE	16 16 4
# 7DIH5I8i_mA	26 26 6
# 7yZNOuJ1usg	26 26 6
# 5Hd3ILLzEyA	26 26 6
# 8YMUHA8xPmk	35 35 8
# 3rhy5b7EvxE	28 28 6
# 1eJ-FQcEIZM	31 31 7
# 3Or1WySN2lo	32 32 7
# 9VDRArH7Q84	25 25 6
# 3TLram1F6dQ	27 27 6
# 7HHxzlqi9_Y	28 28 6
# 53p0lHGXZ2I	Converting to mp4, video file: ./yt8m-av-down-data/train1/53p0lHGXZ2I/53p0lHGXZ2I-video.webm
# 15 15 4
# 3SgaEqdcn2A	40 40 9
# 1vWWamLtg_c	23 23 5
# -CFP5mwX1oE	37YRg7ZlcoQ	30 30 7
# 7NYccP6SxZ8	34 34 7
# 0njioQqIxKY	22 22 5
# AeqPEGryx0U	34 34 7
# 7YtdkGrkgJg	17 17 4
# -HgC-x8JJbg	19gVDPdKmCY	28 28 6
# 7nIn-OOP-Vw	33 33 7
# 8fi4k39ggf4	24 24 5
# 4iVcp0gG2Mk	29 29 6
# 7MvC2CPLvqE	38 38 8
# 8fb6J_ITZOU	54 54 11
# 2znEBy3ghps	42 42 9
# 5zFJTDkYu_M	45 45 10
# 3QXF8rrkyjw	53 53 11
# -wlet7ewQms	3QJbSzoqh8U	45 45 10
# 4AW0K7MaMmo	28 28 6
# 7tsaoN5ivJg	26 26 6
# 96IX76C3Puk	33 33 7
# 7cgCQ-Q1QPU	30 30 7
# -wG3kj51xs8	2U-j8vzEK5c	18 18 4
# BKHaDcF14m4	51 51 11
# 8UJfZenilAM	29 29 6
# 4iRTz8Q1H9g	34 34 7
# 87hSXdLyMNI	Converting to mp4, video file: ./yt8m-av-down-data/train1/87hSXdLyMNI/87hSXdLyMNI-video.webm
# 27 27 6
# 3tLao6zVPIc	16 16 4
# B0AayVP5w9s	0Jmx4xodr8s	39 39 8
# 5PLhYLUFTd8	26 26 6
# 84m-0uO39SY	32 32 7
# 5WV9lV78rwk	41 41 9
# AWEIQgWtyYg	45 45 10
# 3DPSwM68nf4	19 19 4
# 6YIzDW8HBPo	28 28 6
# 2isS2c1lfQk	36 36 8
# BNihzLWN6_s	43 43 9
# 3gAi26J1t9o	18 18 4
# 8ge7eYq9JfQ	54 54 11
# 2R8pt1hRaXw	31 31 7
# 2C07lZZGYqE	36 36 8
# 32Taj2wVsSQ	34 34 7
# 0fFjpBihFCE	48 48 10
# 7VSKqv8CMAc	35 35 8
# BYI6Bt_fNEY	55 55 12
# 5L427DwY5uU	33 33 7
# 6bK1NKNsVaU	23 23 5
# 7d6GA8f2ixY	41 41 9
# 27OXhcMnEug	44 44 9
# 1T4vfFcuAF4	22 22 5
# 1X64V8PA7zE	15 15 4
# 7Tb2BEVtI9o	30 30 7
# 17h7pKUC9s8	26 26 6
# 7RyY7WDmkog	32 32 7
# 48bPpfgZr_A	25 25 6
# 9ly_hFnjH2M	40 40 9
# 8ItZL7uHBQg	39 39 8
# 65dhSZDEc-A	60 60 13
# 7XPTm2iwYc0	28 28 6
# 7PxMJE9MM1g	55 55 12
# 4mYoJ1Pi7No	27 27 6
# BYHaJWDSMtA	25 25 6
# 0uxcMswA01U	34 34 7
# 1UZsesTSl3k	41 41 9
# 47kXhUrsyIw	57 57 12
# 4J39Ol6T0Xw	23 23 5
# 6FgPKyLQRUM	32 32 7
# -Nen5E86Ytk	3lbjnWjm12Q	33 33 7
# 4woDC4Hyb7I	28 28 6
# 1Wer46gvVEY	39 39 8
# 2qy4e9RhB3s	22 22 5
# 7HCflznqGZY	49 49 10
# 6humbyRJqeg	23 23 5
# 1aHu7_SwS4I	24 24 5
# -V3sX51_wag	2EYErVWh7V8	22 22 5
# 1_6P0ejJbmA	21 21 5
# BW-crkQ-Pgw	42 42 9
# 1z7HBcI4Kyo	38 38 8
# 6ch6bi1tSq4	23 23 5
# 4ZxrIbTMJr4	35 35 8
# AdHNooCSScE	33 33 7
# -Q9N7Ugp4Mk	0ALZvT_Docc	34 34 7
# BCHmqhZKwAM	31 31 7
# 7nvsUvgVbYk	34 34 7
# 99HBwCiLi_g	37 37 8
# 4DHHv5OuEzY	27 27 6
# -ioJ3F1U9k4	Ai8z-0zt9Po	31 31 7
# -UdvsknYzmU	3oLsVWlFYJ8	45 45 10
# 7gsz1amx9UA	25 25 6
# 4tygd9yfuog	26 26 6
# 4PMsPX1W95g	28 28 6
# 7QS9IRiHby4	52 52 11
# 4PbYucarE2w	51 51 11
# -JaZdAwcRRE	7tYyyXI42cI	29 29 6
# 4dDbufsrMfI	33 33 7
# 4G6MsM99PEg	28 28 6
# 1XewHajlqEQ	33 33 7
# 7eqAL3iuzy0	34 34 7
# 3P0F93DDO4s	36 36 8
# 1CctNx0_niU	36 36 8
# 1aJa7KrTHf0	36 36 8
# 4_ONPpqH8GY	49 49 10
# 0HskdiCJP1A	42 42 9
# -eeCbkFII0Q	4egntkVDcZ8	26 26 6
# 2Uj7ihvtp4A	34 34 7
# 9QAxaltZ6Z0	29 29 6
# ATMDio5Ry_E	29 29 6
# 0ntKvicJk2U	36 36 8
# 8UcBlYAa05M	40 40 9
# 00ypc1aPiO4	49 49 10
# AXXPKO223k4	56 56 12
# 4UusyIGk2Ms	25 25 6
# 7pAsywaOwzc	41 41 9
# 95CLm_V-2mw	35 35 8
# 3NTlfO1Pyss	37 37 8
# 76_dpzwBkFw	20 20 5
# 64lPq3udHJI	16 16 4
# 7rt0oiL6gSs	18 18 4
# 2Tst4Na6aSs	Converting to mp4, video file: ./yt8m-av-down-data/train1/2Tst4Na6aSs/2Tst4Na6aSs-video.webm
# 21 21 5
# 5St55eWmJ-w	21 21 5
# 0_M3D8uIH7s	28 28 6
# -OFqAlMZJng	2D0MS1iAX-c	18 18 4
# 190ru3AmtNg	17 17 4
# B5bnjoeuoO8	28 28 6
# 8dxQjshCGJ4	20 20 5
# 15hiv41s3o0	49 49 10
# 9upBHQMBzmw	38 38 8
# 5ZlZmwbK6Is	Converting to mp4, video file: ./yt8m-av-down-data/train1/5ZlZmwbK6Is/5ZlZmwbK6Is-video.webm
# 7MQzOXyatak	44 44 9
# 7MZsH6iTKmo	60 60 13
# 5PEajjxv3Ug	26 26 6
# 3jyycGC83mw	30 30 7
# 5-VyVIlBRI0	-7u7IGCmo3Y	7-FsSLwpTSo	35 35 8
# 1P80ruQCQbA	28 28 6
# 0pyP7UDIuqI	47EcMFVe2P4	16 16 4
# 8LVtpeGWD9o	61 61 13
# 1RCcpbnU3Dk	22 22 5
# 8UCiLhpRSdc	20 20 5
# 6N0ughKVm4M	26 26 6
# 4F6dzDB62RA	28 28 6
# -THE3h6FTgo	2EkxDoHHdYI	7MQB40QJZQ4	32 32 7
# 2gmPCbOBepE	51 51 11
# 3McRF8_SzzM	52 52 11
# 38SojIdVeLQ	36 36 8
# 0JJJyYFf-5g	36 36 8
# 0LSGvziX_6Y	26 26 6
# 52wwumRgqVo	31 31 7
# 73cskqz8hnE	35 35 8
# AsEA7VeSiN0	22 22 5
# 4e-jCx-4Vx0	33 33 7
# 2EI8sZKKQeA	29 29 6
# 0SKfHjffG88	43 43 9
# 4qKyGKYU9nw	20 20 5
# 7w3Uhe7e_1o	61 61 13
# -qUMJ-GQeOA	9e469X4GU74	31 31 7
# 7rcx_RbuVUM	36 36 8
# A0eswm8YCps	31 31 7
# Ai578_rqk9w	29 29 6
# 9YOa7uJAZ8U	31 31 7
# 0mU0UpHxLqo	25 25 6
# 6-LwBTwR6eI	15 15 4
# 8OqCVK2HhSo	35 35 8
# 4BlGKDnUzWs	34 34 7
# 1eJlBbxFl6Q	23 23 5
# BUgMxiqdDvs	38 38 8
# Ag3UIMaUmeA	55 55 12
# 00sUzdkwFGA	26 26 6
# 7Ae5d1w9xtY	30 30 7
# 4quJ1uTmFw8	32 32 7
# 7G0GeSJCGKA	35 35 8
# AQyMH5GTrGI	24 24 5
# ASDUU6kI4kI	33 33 7
# APxI9gE6zPY	53 53 11
# 9q7mzAhPGYM	38 38 8
# 098uxRSVTUU	26 26 6
# 4C4IeliJebQ	36 36 8
# 0VuQgs7T4Og	36 36 8
# 6OYG1_EZ9d0	33 33 7
# 7t_2rhO360o	26 26 6
# A1EFwoO03gA	18 18 4
# 5wFFKzT85Cg	39 39 8
# Aybyx9188t0	60 60 13
# 0uZNPeaWX2k	25 25 6
# 5QronMsLB4s	21 21 5
# 3HbIeRBp3aw	1Bswz7p-vOE	29 29 6
# 7J7on71JlWY	25 25 6
# 8Od3l6VjlEY	59 59 12
# 4eomf_cUPQY	31 31 7
# BGI_qlUO9RM	40 40 9
# -ccnoEe3qFQ	62ki5vfFSJQ	19 19 4
# 51-Bo5ff8ac	25 25 6
# AFqvDfzC8RA	36 36 8
# AnkH35Z_h4k	24 24 5
# 9GjZrNGx_cc	26 26 6
# 6_dDVLjMFuQ	29 29 6
# 9KOnBUvHrk8	Converting to mp4, video file: ./yt8m-av-down-data/train1/9KOnBUvHrk8/9KOnBUvHrk8-video.webm
# 25 25 6
# 4xafCW7nCM0	27 27 6
# 2HcKilfrnWk	41 41 9
# A4FGn_0NkhU	Converting to mp4, video file: ./yt8m-av-down-data/train1/A4FGn_0NkhU/A4FGn_0NkhU-video.webm
# 33 33 7
# 2jhlloGpJhY	30 30 7
# 5RWobV0YqLU	Converting to mp4, video file: ./yt8m-av-down-data/train1/5RWobV0YqLU/5RWobV0YqLU-video.webm
# 21 21 5
# 61uOVqjCVo4	26 26 6
# 5O8k8Ppi6vo	39 39 8
# 9BzN8MMXHYg	Converting to mp4, video file: ./yt8m-av-down-data/train1/9BzN8MMXHYg/9BzN8MMXHYg-video.webm
# 6l9kjPBQQZE	15 15 4
# BRS_Y33LNS8	34 34 7
# 42Tun6AewLM	30 30 7
# 9c8edtK5iGw	18 18 4
# 84DlxkTFkAM	29 29 6
# 8tkI4K4iMT4	43 43 9
# 8UVjm5RfKB8	30 30 7
# 31ZxZkPEx9g	Converting to mp4, video file: ./yt8m-av-down-data/train1/31ZxZkPEx9g/31ZxZkPEx9g-video.webm
# 27 27 6
# -6iyUwaED24	BcHHK4lhWQw	27 27 6
# 33FfG0HDbHM	22 22 5
# 9VpoE4XbJwo	28 28 6
# 9FC2s0gfomo	23 23 5
# 5-ZphaFANgY	16 16 4
# 3jBqNFQb068	42 42 9
# 24MsLdHfUM4	38 38 8
# Az6UNFdEEys	48 48 10
# 0_5gJttX_as	28 28 6
# 6vKE1Ix6BPQ	34 34 7
# 3TdJeg0PK-0	30 30 7
# -kZMfLULwHA	3HOju8xyDR0	28 28 6
# 3iWRqIW232g	39 39 8
# 5nJAyKF7iWo	25 25 6
# AH6uo9nDAjY	38 38 8
# 8M7LS3Ir0Wg	27 27 6
# 2OXZHR_Ar00	31 31 7
# BQwSYZUv-rY	27 27 6
# 7fZYgTHuWXQ	21 21 5
# 8ETkROy1RBs	32 32 7
# A4aj5FceVqc	29 29 6
# 0BtjNMPiWX0	26 26 6
# 9I5Lxdv5bXU	17 17 4
# 6rZL3axZNmI	40 40 9
# 7oLzLM0vqks	25 25 6
# 8ID-7dSB1zQ	19 19 4
# 7pbnT3HeLZg	22 22 5
# 4q57gYAtCqE	15 15 4
# 8uVqaDB_6Jk	47 47 10
# 8PiBvPVw-Vk	18 18 4
# 9L_gZQOBUKE	28 28 6
# BeSPFaNq2AQ	32 32 7
# 4AWqf2lgBHk	49 49 10
# AEXNC9GB5gc	35 35 8
# 1h_-G6Hp0HI	38 38 8
# 5-Hv2li_OL0	21 21 5
# 68w-dUkGUss	17 17 4
# -dVL86g0zfY	9lHQMXob9Ik	29 29 6
# 1QO191imv0s	24 24 5
# 7he6uvw4gRc	32 32 7
# 903GZKqeBeQ	20 20 5
# 07pWRptD_8c	24 24 5
# 0tkRstTn9CM	21 21 5
# 3vpdlrOyKCI	26 26 6
# 4EdKb8uQM2A	40 40 9
# BIm0kOa65Do	54 54 11
# 2ztnP6FIP1Y	31 31 7
# 79CHtJ9g3ao	38 38 8
# 9moD9c9W7BE	44 44 9
# -6JjOTpyHIg	1m4CNsPa9Zg	50 50 11
# 5WT17jg9RDU	33 33 7
# 5j_LdJW9Pc4	25 25 6
# 3IvCk1MensU	25 25 6
# -a7fc_2lkhA	5IuDzoOUC9o	28 28 6
# 6oTYATU29XI	30 30 7
# 4TINf0LQ9eg	24 24 5
# 6o6tWSacXnI	4Aa8Gc41q7I	31 31 7
# 5vTUtfKgWwg	43 43 9
# 1Crx9LCRTas	27 27 6
# 9aQ0aFA6mak	30 30 7
# AdMzJbJitxk	33 33 7
# 0wgcljBdd5g	20 20 5
# BdIuOu8Ruqw	28 28 6
# 8OkH2dAQ9lU	43 43 9
# 53ebKv1lYWw	32 32 7
# -ulVe3Tv_6M	94T4OuFm16U	33 33 7
# 6aetTCmhehE	45 45 10
# 6GUlh4OOkgo	34 34 7
# AceSIlK4ixU	23 23 5
# -xw4KT7SKss	918xgakTV80	30 30 7
# 5Dl1SDD97kk	25 25 6
# 0eQnlcSfe3w	31 31 7
# -njov1xRWxA	310QWH4XpAw	26 26 6
# 1z_Cdi4laWY	29 29 6
# 5AYFxeQUtSA	40 40 9
# 9uomQJhklVg	32 32 7
# A-K00Jqg9CA	Converting to mp4, video file: ./yt8m-av-down-data/train1/A-K00Jqg9CA/A-K00Jqg9CA-video.webm
# 8TetiHYH3BE	55 55 12
# 5a9K7kist5k	44 44 9
# 7wE1-zVbnzY	35 35 8
# 0JHMSfx7wns	23 23 5
# 2WzCzznSG4w	28 28 6
# 66f7jvHrsVw	29 29 6
# 2EZuf6ascFY	31 31 7
# 6UrZjAOil38	21 21 5
# 153wqAS2Tqw	23 23 5
# 4AtKgEX8QQI	32 32 7
# 6JyuC7-0KEo	25 25 6
# AohgbRA7hIw	29 29 6
# -Eq4OlN1zYI	7UyYfV300_I	26 26 6
# 8DS-h67qEiY	26 26 6
# 07JhpCRHvtY	31 31 7
# 3SlzOHl6QO0	59 59 12
# 95TFSriXv3I	-K5lS8qybMw	AruCkuOgwSA	20 20 5
# 8XPRMZdwW7s	43 43 9
# 8uDEQFaYCSY	44 44 9
# B_8Z8NjgYOo	27 27 6
# 20DXLVtCaGM	49 49 10
# 4p3hhab9QaU	27 27 6
# 6x23NrXgXH4	21 21 5
# 63GN3fEWs4A	15 15 4
# 17a7mnbcYfE	38 38 8
# 3G9KK3U3Xok	17 17 4
# 1fAxJupA2qI	45 45 10
# 7r-W4oIedhk	25 25 6
# 3UoFEJ4e8KA	28 28 6
# 2pikTYIZkjY	57 57 12
# -hHQPnKZBI0	4LqL0J8zv8Y	24 24 5
# 4FcmbQmK4Do	27 27 6
# 28bFBH4hIvE	40 40 9
# 10_REPqPlP0	30 30 7
# -WHiYQvVMKM	1GxF7tyj_Eg	28 28 6
# 9dPar5_Jn9U	31 31 7
# 3EXkkHSPyJU	34 34 7
# 1uKDNHgJrcI	23 23 5
# 1BnTS-2ZjAA	38 38 8
# 7BWtzZefENo	32 32 7
# 8aiLA28lY3I	29 29 6
# 4A-a8novGjo	22 22 5
# 3EglvZ2TIC8	Converting to mp4, video file: ./yt8m-av-down-data/train1/3EglvZ2TIC8/3EglvZ2TIC8-video.webm
# 52 52 11
# 2q21Ru3of30	42 42 9
# 34Dwb4ADGrA	24 24 5
# 36mqKeGkDoQ	41 41 9
# 935VJJ8ykTI	34 34 7
# 9OPFeM9fZxA	29 29 6
# 8cb1ZrS6HLQ	40 40 9
# 5yqbmhpNEKU	41 41 9
# -8rtCEiYH1Y	8hVkWoxKuOc	31 31 7
# Ar4XgptLhkY	32 32 7
# 36Xt-XeWnHM	47 47 10
# 6Cn8byWKXx0	21 21 5
# 2HHWKa1ycKc	38 38 8
# 0214BFaWloo	32 32 7
# 3mz_Q7cH34A	36 36 8
# 1F-G4sR_PbY	30 30 7
# 9iHoZZTHHJo	36 36 8
# -O6OdhaQ2Rk	5JoV6m8SwF0	34 34 7
# 0tcSh2GG0OE	16 16 4
# 8tFqhUYZCFk	21 21 5
# 1gPKELu8Kh0	20 20 5
# 5Dp3aohf384	32 32 7
# 9--GYkV0Oa4	41 41 9
# 42UpcHtpies	Converting to mp4, video file: ./yt8m-av-down-data/train1/42UpcHtpies/42UpcHtpies-video.webm
# 27 27 6
# 5rl7L9Vac6Y	23 23 5
# 52eiA9RgkTQ	25 25 6
# 1EC95T1dNhU	54 54 11
# 3dtNTHMPmQ0	17 17 4
# 34alCViRPYk	30 30 7
# 15qXfgqznCI	47 47 10
# -Ew5dPQStvk	6BAy_IjblEM	36 36 8
# AlYTPYr5Y2s	54 54 11
# AGnASupPagc	31 31 7
# 5sIxvor2YwM	38 38 8
# -DlLuxnV-u8	6RJNGDIimNM	1fqdEQSAy40	34 34 7
# 4c2_1oRS0eg	30 30 7
# 7hWooG3Y8yk	42 42 9
# 5r76abJnSoU	48 48 10
# 0x9C9HWj9YM	15 15 4
# 2hyibXdOp5w	29 29 6
# 34RBzUp31UE	30 30 7
# 35ydVKaTHTU	22 22 5
# 7G3NGVjychk	33 33 7
# 9d8Uf1tW2_8	30 30 7
# AuH59wPe28k	31 31 7
# 1P5nX8ZBacI	27 27 6
# 5cGq3S0Mgmg	26 26 6
# 7Xnid2dLFYo	29 29 6
# 59d095Uc74Q	Converting to mp4, video file: ./yt8m-av-down-data/train1/59d095Uc74Q/59d095Uc74Q-video.webm
# 27 27 6
# 9yRhNp6ahUM	41 41 9
# 5z8eoS37XfQ	28 28 6
# 7nQYcXvuug0	19 19 4
# 0W6TimpTCp4	21 21 5
# 7LtHaAekTdk	39 39 8
# 6XZLJT_B9tQ	31 31 7
# 9VhODEaoFdc	41 41 9
# 1jyhC6FrEtY	28 28 6
# A-AS07rFTb4	16 16 4
# 2rIz4XtaiIU	37 37 8
# 2UfDb47H8J4	Converting to mp4, video file: ./yt8m-av-down-data/train1/2UfDb47H8J4/2UfDb47H8J4-video.webm
# 25 25 6
# 6ugf_yb_sDM	26 26 6
# Ap_BRZ6BgWo	20 20 5
# 9vD0JBuZ16w	34 34 7
# 3IaVCiFLWmE	39 39 8
# 3JbyiOpREZU	17 17 4
# ANkArg6WIPU	34 34 7
# AtyMd1FEEvY	22 22 5
# 8XLO2IaOwZk	34 34 7
# AVpIRKQfn24	41 41 9
# 5OflJML1yF8	41 41 9
# AQF4qlydbIc	Converting to mp4, video file: ./yt8m-av-down-data/train1/AQF4qlydbIc/AQF4qlydbIc-video.webm
# 54 54 11
# 4DrqZbf3bII	31 31 7
# BCOYMkZ36-E	Converting to mp4, video file: ./yt8m-av-down-data/train1/BCOYMkZ36-E/BCOYMkZ36-E-video.webm
# 41 41 9
# 0PKiPtYVznM	34 34 7
# 4ZAqdI-XRkI	30 30 7
# BX9qsilzP8Q	15 15 4
# 9LU-3rNZev0	38 38 8
# 7w3ge7c83TY	28 28 6
# 9d8BhIkwnCY	24 24 5
# 0sdK4VTsjHY	26 26 6
# 6oUO2oRNFUQ	25 25 6
# 7c6Zrd8AVL8	34 34 7
# 08bYVLHWJ2c	48 48 10
# 0mDYKN-pkK0	28 28 6
# -jv68mYWNQI	8azx79q2gQs	17 17 4
# -mhsRocHToQ	1dNiWj3nhfU	32 32 7
# 6VJLVN-q9Fs	28 28 6
# 6uwop6C53bo	28 28 6
# 5BxV4UimG1s	23 23 5
# -RWeqRIrbqY	8hx7zDZffqU	17 17 4
# 6hObj58KTjU	ArPsYL9XXlA	21 21 5
# AkdPRERGmxA	26 26 6
# BOS4W5-zKJ8	32 32 7
# 6M8cL5-vPvE	30 30 7
# 9WhS8wXS1xU	25 25 6
# 7rSM6cXKkjg	26 26 6
# BGMKUQ2Fdlc	31 31 7
# 6xIkWuaQClU	20 20 5
# 9jARpJe7X2U	24 24 5
# 8YfUth-DHM4	57 57 12
# 5NX__PfHSwU	31 31 7
# 8bpqVTnWjBY	29 29 6
# 0-tCXPvxEPI	59 59 12
# 1KUi8WbRrV0	19 19 4
# 3VVOqcfUAD4	23 23 5
# 3YkJZZ5Tdxk	33 33 7
# 48ecotJKbC8	28 28 6
# 2z3FNBKgWTo	21 21 5
# 2PmhcwNknH0	Converting to mp4, video file: ./yt8m-av-down-data/train1/2PmhcwNknH0/2PmhcwNknH0-video.webm
# 22 22 5
# 11Fb_K1aRSM	26 26 6
# 2PXL168qQAk	39 39 8
# AD71alhqCqQ	15 15 4
# 0jfVb4xyPQI	22 22 5
# 0y03D0GJgfA	Converting to mp4, video file: ./yt8m-av-down-data/train1/0y03D0GJgfA/0y03D0GJgfA-video.webm
# 32 32 7
# 4EYfkE6fczE	28 28 6
# -GcWU-eG3bU	BFTCKfmSN58	33 33 7
# 3G_EYTM1nyU	39 39 8
# 3ABkgrocGi8	28 28 6
# 0e4WJRDqahk	34 34 7
# AZYewmDLoMs	39 39 8
# 8dv8rsjnOLo	36 36 8
# 8BFGMjHFm1k	35 35 8
# BTPQlbAfesg	33 33 7
# AP9silv2EUg	30 30 7
# 2RNKO-bt8Hs	41 41 9
# 4qYr7zeSnOg	29 29 6
# 3-nXM3y4iDo	27 27 6
# 4ibcjgWbS50	25 25 6
# -mAYfyFxPiw	4JhYuMVfuBc	28 28 6
# 7edWQ-PHz-Y	35 35 8
# 7e6lr-_Tfko	29 29 6
# 4RQnSnnkKPk	45 45 10
# 7pZEA4xGLDM	48 48 10
# 23Ef8V3vkM8	26 26 6
# -POkVG2nmL0	5Nio37ESmmA	55 55 12
# AmGIPdJ4AA0	46 46 10
# 5f1K8WOPLWc	57 57 12
# 61c9_avmN9A	34 34 7
# 4QAbl3sbHVo	38 38 8
# 37ZANBHQllI	Converting to mp4, video file: ./yt8m-av-down-data/train1/37ZANBHQllI/37ZANBHQllI-video.webm
# 31 31 7
# -pc42_tE2iw	49IzRhspojM	25 25 6
# 7G_wKxJMdzg	45 45 10
# 91Q-8zyN6hg	29 29 6
# 0Ci7bqJl9nc	20 20 5
# 87sdTRcmz5o	23 23 5
# 4qLajDINWEk	Converting to mp4, video file: ./yt8m-av-down-data/train1/4qLajDINWEk/4qLajDINWEk-video.webm
# 6Eit_GJ8q-U	5nFMwqx1_kc	27 27 6
# 6cl7oJbYgIo	55 55 12
# AiPHukMBtXI	25 25 6
# 58loaObqvDc	29 29 6
# 4EvcqlOJ5I0	23 23 5
# -_L7zDD6IeE	B2UNVN1dPGo	53 53 11
# 10AmpTawwJg	27 27 6
# 4ZCGXqqMM6Y	42 42 9
# 58A1vkqwXX4	43 43 9
# 7eOooXvLyZY	37 37 8
# 0hzSpDlyC5g	22 22 5
# 2jNfqgSmrZY	37 37 8
# 3upIWNuZmSM	15 15 4
# 8Hh8ACgZI8I	48 48 10
# 4Umrb9LQVT0	44 44 9
# 3_zU1coEkjw	33 33 7
# 3sj2Lo7FBE8	21 21 5
# 0_hdEBced4g	Converting to mp4, video file: ./yt8m-av-down-data/train1/0_hdEBced4g/0_hdEBced4g-video.webm
# 22 22 5
# ANf2d1Yjib0	21 21 5
# 0f18t2txqDU	45 45 10
# 9WNkSUuyQbA	25 25 6
# 7hyXfg81h0U	61 61 13
# -u3f_e3tBNI	4trFXsbOW0A	29 29 6
# 0STQwIiXA54	47 47 10
# 4NjfGc5gK30	30 30 7
# 8Vre0u2yH7w	22 22 5
# 1N-UMbJyUvk	23 23 5
# 9C76Rv-3L-4	37 37 8
# 2wQeMq_6cnw	56 56 12
# 4ldM02jYMQ0	5bRbR2HQkdA	36 36 8
# 5WOGD46j9gw	34 34 7
# 5cvxz1eBcXE	34 34 7
# 3P0u7ZSlNXA	30 30 7
# 9WzJs_I6rNI	33 33 7
# B5jkw_WkBHo	31 31 7
# 3VKuGOHrmhs	41 41 9
# 4WIs_rEWewk	38 38 8
# 5tstNxwHMh4	22 22 5
# 7dtHtvnZ_qQ	18 18 4
# 9ToomEjezpU	37 37 8
# AsDMPs0MOLI	5ywM1OVczjI	0o10evshk2A	6Old4NOWWyQ	Converting to mp4, video file: ./yt8m-av-down-data/train1/6Old4NOWWyQ/6Old4NOWWyQ-video.webm
# 23 23 5
# 6EVjD-QSoRM	23 23 5
# 1Js9eqDnJt8	24 24 5
# 0hJsSuZCg1Q	18 18 4
# -eDGpdv-bHM	5-8W0eNYMRw	41 41 9
# 0-Qlr4GSoKk	32 32 7
# 8yEzBxp36Sg	42 42 9
# 5mkZC64494Y	36 36 8
# 70wvE5MnzVs	37 37 8
# 4VAaoCqOA_I	43 43 9
# 7Fhq_kUxwak	Converting to mp4, video file: ./yt8m-av-down-data/train1/7Fhq_kUxwak/7Fhq_kUxwak-video.webm
# 25 25 6
# -C-ouaJB-U4	0fHzNFZdzcY	46 46 10
# -m7M6j1w1mQ	-aJPNHKeJPw	0GBAycf6nAQ	29 29 6
# AUnpi9Q3f8s	27 27 6
# BLYa1GOfbh8	31 31 7
# 5ACVIZsTR-U	48 48 10
# -haY0ihr65Q	3ygftj4gqR8	33 33 7
# 1Bg1qAw8TmM	27 27 6
# BYR8ml63hnU	25 25 6
# ABphGdXNRsc	32 32 7
# 9gCQsyzLduw	57 57 12
# 3iJo-ziOMLE	24 24 5
# 2-UnCgUGL1w	36 36 8
# 8gAALonPoO0	30 30 7
# 0nkj-jQzxAA	28 28 6
# 79WWebCZtFE	36 36 8
# 68SVqpykpo0	56 56 12
# 6rnDIf3Z938	28 28 6
# 3A8j_4KVgt0	26 26 6
# 8Ud1PNXSZ3U	5hkZ7WwoGrU	42 42 9
# AOTByV0Mod0	25 25 6
# 1N8VD3KNcdk	28 28 6
# 2MhF1noJpX4	28 28 6
# 47-thDq76kA	30 30 7
# APP6-4i_pR4	6fdic7vOj6I	21 21 5
# 3kgLqciahlQ	38 38 8
# 7GS4QmDQbFw	22 22 5
# 8hVPyfXLn9E	17 17 4
# 59hSDpkk-Lo	41 41 9
# 78lBsLJLB9U	45 45 10
# 5mVMXqMavGA	38 38 8
# 9dnEO4j460U	Converting to mp4, video file: ./yt8m-av-down-data/train1/9dnEO4j460U/9dnEO4j460U-video.webm
# 30 30 7
# 6T9Pd7EMy8I	49 49 10
# 3f1KIOl9Ne8	60 60 13
# 89fj72C3mug	26 26 6
# 1F2K7w56QpA	38 38 8
# 4awp5blLLUI	5Q1ADGvQjU8	24 24 5
# 9lrVd5WVACI	48 48 10
